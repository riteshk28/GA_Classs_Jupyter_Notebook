# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
path = 'D:\\MyData\\GreyAtom\\Python\\Jupyter\\sanfransisco_crime.csv'
crime_d1 = pd.read_csv(path, delimiter=',')
crime_d1.head(10)
# Out:
#                  Dates        Category                        Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                  WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 5  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO
# 6  2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 7  2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 8  2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 9  2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                        Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED             OAK ST / LAGUNA ST
# ...

# %%
crime_d1['count'] = 1
d2 = crime_d1.pivot_table('count', aggfunc=np.sum, index='PdDistrict', columns='Category')
d2.head(10)
# Out:
# Category    ARSON  ASSAULT  BAD CHECKS  BRIBERY  BURGLARY  DISORDERLY CONDUCT  \
# PdDistrict
# BAYVIEW     393.0   9857.0        34.0     56.0    3930.0               219.0
# CENTRAL     111.0   6977.0        65.0     12.0    4519.0               494.0
# INGLESIDE   182.0   8533.0        32.0     53.0    3331.0               171.0
# MISSION     145.0  11149.0        46.0     66.0    3745.0              1099.0
# NORTHERN    149.0   8318.0        54.0     18.0    5854.0               452.0
# PARK         65.0   3515.0        15.0      7.0    2888.0               271.0
# RICHMOND    103.0   3202.0        31.0      8.0    2696.0               108.0
# SOUTHERN    185.0  12183.0        74.0     37.0    4841.0               511.0
# TARAVAL     120.0   5463.0        36.0     17.0    3463.0               162.0
# TENDERLOIN   60.0   7679.0        19.0     15.0    1488.0               833.0
#
# Category    DRIVING UNDER THE INFLUENCE  DRUG/NARCOTIC  DRUNKENNESS  \
# PdDistrict
# ...

# %%
cat_count = crime_d1.groupby(['PdDistrict', 'Category'])
cat_file = cat_count['Category'].count() #grouped. Gives category and district wise count
cat_file.head(10)
# Out:
# PdDistrict  Category
# BAYVIEW     ARSON                           393
#             ASSAULT                        9857
#             BAD CHECKS                       34
#             BRIBERY                          56
#             BURGLARY                       3930
#             DISORDERLY CONDUCT              219
#             DRIVING UNDER THE INFLUENCE     179
#             DRUG/NARCOTIC                  4498
#             DRUNKENNESS                     243
#             EMBEZZLEMENT                    100
# Name: Category, dtype: int64

# %%
total_bayview = cat_file['BAYVIEW'].sum(axis=0)
total_bayview
# Out:
# 89431L

# %%
cat_file['TARAVAL']['ASSAULT']
# Out:
# 5463

# %%
crime_d1.head(10)
# Out:
#                  Dates        Category                        Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                  WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 5  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO
# 6  2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 7  2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 8  2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 9  2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                        Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED             OAK ST / LAGUNA ST
# ...

# %%
crime_d1[crime_d1['Category'] == 'WARRANTS'].count() # count of total warrants
# Out:
# Dates         42214
# Category      42214
# Descript      42214
# DayOfWeek     42214
# PdDistrict    42214
# Resolution    42214
# Address       42214
# X             42214
# Y             42214
# count         42214
# dtype: int64

# %%
#d2 is our pivoted data. Lets check max ASSAULT in d2
d2.head(3)
d2.sort_values(by='ASSAULT', ascending=False)
# Out:
# Category    ARSON  ASSAULT  BAD CHECKS  BRIBERY  BURGLARY  DISORDERLY CONDUCT  \
# PdDistrict
# SOUTHERN    185.0  12183.0        74.0     37.0    4841.0               511.0
# MISSION     145.0  11149.0        46.0     66.0    3745.0              1099.0
# BAYVIEW     393.0   9857.0        34.0     56.0    3930.0               219.0
# INGLESIDE   182.0   8533.0        32.0     53.0    3331.0               171.0
# NORTHERN    149.0   8318.0        54.0     18.0    5854.0               452.0
# TENDERLOIN   60.0   7679.0        19.0     15.0    1488.0               833.0
# CENTRAL     111.0   6977.0        65.0     12.0    4519.0               494.0
# TARAVAL     120.0   5463.0        36.0     17.0    3463.0               162.0
# PARK         65.0   3515.0        15.0      7.0    2888.0               271.0
# RICHMOND    103.0   3202.0        31.0      8.0    2696.0               108.0
#
# Category    DRIVING UNDER THE INFLUENCE  DRUG/NARCOTIC  DRUNKENNESS  \
# PdDistrict
# ...

# %%
d2.head(5)
# Out:
# Category    ARSON  ASSAULT  BAD CHECKS  BRIBERY  BURGLARY  DISORDERLY CONDUCT  \
# PdDistrict
# BAYVIEW     393.0   9857.0        34.0     56.0    3930.0               219.0
# CENTRAL     111.0   6977.0        65.0     12.0    4519.0               494.0
# INGLESIDE   182.0   8533.0        32.0     53.0    3331.0               171.0
# MISSION     145.0  11149.0        46.0     66.0    3745.0              1099.0
# NORTHERN    149.0   8318.0        54.0     18.0    5854.0               452.0
#
# Category    DRIVING UNDER THE INFLUENCE  DRUG/NARCOTIC  DRUNKENNESS  \
# PdDistrict
# BAYVIEW                           179.0         4498.0        243.0
# CENTRAL                           160.0         1805.0        517.0
# INGLESIDE                         206.0         2373.0        190.0
# MISSION                           357.0         8757.0        782.0
# NORTHERN                          260.0         4511.0        368.0
#
# ...

# %%
d2['ASSAULT'].mean() #mean of assaults in all districts
# Out:
# 7687.6

# %%
type(d2)
# Out:
# pandas.core.frame.DataFrame

# %%
bayview_plot = d2.loc['BAYVIEW']

# %%
bayview_plot.plot(kind='bar')
plt.show()
